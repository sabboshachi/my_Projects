# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/ML/updated/SQPH_HistoricalPrices - SQPH_HistoricalPrices.csv')

# %%
df
# Out:
#             Date    Open    High     Low   Close       Volume
# 0     1997-07-07    3.11    3.11    3.11    3.11  720979.6857
# 1     1997-07-08    3.09    3.09    3.09    3.09  455044.5557
# 2     1997-07-09    3.07    3.07    3.07    3.07  602786.2946
# 3     1997-07-10    3.08    3.08    3.08    3.08  319122.1560
# 4     1997-07-14    2.92    2.92    2.92    2.92  307302.8169
# ...          ...     ...     ...     ...     ...          ...
# 4401  2022-08-04  213.60  216.80  213.00  216.10  590946.0000
# 4402  2022-08-08  215.00  215.00  212.50  213.50  178656.0000
# 4403  2022-08-10  215.00  215.00  211.30  213.10  129413.0000
# 4404  2022-08-11  213.90  214.00  211.00  211.60   74760.0000
# 4405  2022-08-16  213.00  213.30  212.50  212.80  153858.0000
#
# [4406 rows x 6 columns]

# %%
df = df[['Date', 'Close']]
df.head(10)
# Out:
#          Date  Close
# 0  1997-07-07   3.11
# 1  1997-07-08   3.09
# 2  1997-07-09   3.07
# 3  1997-07-10   3.08
# 4  1997-07-14   2.92
# 5  1997-07-16   2.96
# 6  1997-07-17   2.99
# 7  1997-07-21   2.83
# 8  1997-07-22   2.81
# 9  1997-07-23   2.82

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('2010-08-23')
datetime_object
# Out:
# datetime.datetime(2010, 8, 23, 0, 0)

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Date']
# Out:
# 0      1997-07-07
# 1      1997-07-08
# 2      1997-07-09
# 3      1997-07-10
# 4      1997-07-14
#           ...
# 4401   2022-08-04
# 4402   2022-08-08
# 4403   2022-08-10
# 4404   2022-08-11
# 4405   2022-08-16
# Name: Date, Length: 4406, dtype: datetime64[ns]

# %%
df.index = df.pop('Date')

# %%
df.index
# Out:
# DatetimeIndex(['1997-07-07', '1997-07-08', '1997-07-09', '1997-07-10',
#                '1997-07-14', '1997-07-16', '1997-07-17', '1997-07-21',
#                '1997-07-22', '1997-07-23',
#                ...
#                '2022-07-27', '2022-07-28', '2022-08-01', '2022-08-02',
#                '2022-08-03', '2022-08-04', '2022-08-08', '2022-08-10',
#                '2022-08-11', '2022-08-16'],
#               dtype='datetime64[ns]', name='Date', length=4406, freq=None)

# %%
import matplotlib.pyplot as plt

plt.plot(df.index, df['Close'])

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date
  #print(target_date)
  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+2)
    #print(df_subset)
    
    if len(df_subset) != n+2:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=100)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))
    
    if last_time:
      break
    
    target_date = next_date

    if target_date == last_date:
      last_time = True
    
  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates
  
  X = np.array(X)
  for i in range(0, n+1):
    X[:, i]
    ret_df[f'Target-{n+1-i}'] = X[:, i]
  
  ret_df['Target'] = Y

  return ret_df

# %%
# Start day second time around: '2021-03-25'
windowed_df = df_to_windowed_df(df, 
                                '2010-08-23', 
                                '2022-08-11',                         
                                n=5)
windowed_df
# Out:
#      Target Date  Target-6  Target-5  Target-4  Target-3  Target-2  Target-1  \
# 0     2010-08-23     69.92     69.78     68.66     67.94     67.50     68.10
# 1     2010-08-24     69.78     68.66     67.94     67.50     68.10     68.05
# 2     2010-08-25     68.66     67.94     67.50     68.10     68.05     68.63
# 3     2010-08-30     67.94     67.50     68.10     68.05     68.63     68.25
# 4     2010-08-31     67.50     68.10     68.05     68.63     68.25     68.79
# ...          ...       ...       ...       ...       ...       ...       ...
# 2266  2022-08-03    210.00    210.50    209.90    208.90    210.70    212.10
# 2267  2022-08-04    210.50    209.90    208.90    210.70    212.10    213.40
# 2268  2022-08-08    209.90    208.90    210.70    212.10    213.40    216.10
# 2269  2022-08-10    208.90    210.70    212.10    213.40    216.10    213.50
# 2270  2022-08-11    210.70    212.10    213.40    216.10    213.50    213.10
#
#       Target
# 0      68.05
# 1      68.63
# 2      68.25
# 3      68.79
# 4      67.90
# ...      ...
# 2266  213.40
# 2267  216.10
# 2268  213.50
# 2269  213.10
# 2270  211.60
#
# [2271 rows x 8 columns]

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((2271,), (2271, 6, 1), (2271,))

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90,]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((6, 1)),
                    layers.LSTM(128),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse', optimizer=Adam(learning_rate=0.001), metrics=['mean_absolute_error'])

# model.compile(
#     optimizer=Adam(learning_rate=0.001),
#     loss='mse',
#     metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.2775 - mean_absolute_error: 1.8370 - val_loss: 15.2290 - val_mean_absolute_error: 2.9544
# Epoch 2/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.1733 - mean_absolute_error: 1.8201 - val_loss: 12.8632 - val_mean_absolute_error: 2.6828
# Epoch 3/100
# 57/57 [==============================] - 1s 18ms/step - loss: 7.3324 - mean_absolute_error: 1.9786 - val_loss: 24.5593 - val_mean_absolute_error: 4.2877
# Epoch 4/100
# 57/57 [==============================] - 1s 19ms/step - loss: 6.8990 - mean_absolute_error: 1.9509 - val_loss: 10.5606 - val_mean_absolute_error: 2.1101
# Epoch 5/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.3252 - mean_absolute_error: 1.8268 - val_loss: 12.3450 - val_mean_absolute_error: 2.5843
# Epoch 6/100
# 57/57 [==============================] - 1s 11ms/step - loss: 7.1001 - mean_absolute_error: 1.9531 - val_loss: 13.9541 - val_mean_absolute_error: 2.7536
# Epoch 7/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.2186 - mean_absolute_error: 1.8036 - val_loss: 10.6640 - val_mean_absolute_error: 2.1630
# Epoch 8/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.2220 - mean_absolute_error: 1.6416 - val_loss: 11.0631 - val_mean_absolute_error: 2.2255
# Epoch 9/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.7714 - mean_absolute_error: 1.7446 - val_loss: 10.8535 - val_mean_absolute_error: 2.1568
# Epoch 10/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.4744 - mean_absolute_error: 1.8386 - val_loss: 11.3397 - val_mean_absolute_error: 2.2690
# Epoch 11/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.6336 - mean_absolute_error: 1.7048 - val_loss: 10.7236 - val_mean_absolute_error: 2.1690
# Epoch 12/100
# 57/57 [==============================] - 1s 11ms/step - loss: 4.7887 - mean_absolute_error: 1.5166 - val_loss: 12.1358 - val_mean_absolute_error: 2.4450
# Epoch 13/100
# 57/57 [==============================] - 1s 11ms/step - loss: 4.7424 - mean_absolute_error: 1.5302 - val_loss: 10.9344 - val_mean_absolute_error: 2.1772
# Epoch 14/100
# 57/57 [==============================] - 1s 12ms/step - loss: 4.6534 - mean_absolute_error: 1.4912 - val_loss: 15.3994 - val_mean_absolute_error: 2.9689
# Epoch 15/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.8145 - mean_absolute_error: 1.9384 - val_loss: 13.4898 - val_mean_absolute_error: 2.8034
# Epoch 16/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.5494 - mean_absolute_error: 1.8533 - val_loss: 17.3167 - val_mean_absolute_error: 3.2443
# Epoch 17/100
# 57/57 [==============================] - 1s 11ms/step - loss: 7.4361 - mean_absolute_error: 2.0201 - val_loss: 28.3142 - val_mean_absolute_error: 4.5555
# Epoch 18/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.8331 - mean_absolute_error: 1.7527 - val_loss: 13.8363 - val_mean_absolute_error: 2.7288
# Epoch 19/100
# 57/57 [==============================] - 1s 11ms/step - loss: 4.9988 - mean_absolute_error: 1.5998 - val_loss: 11.0660 - val_mean_absolute_error: 2.1848
# Epoch 20/100
# 57/57 [==============================] - 1s 12ms/step - loss: 4.7591 - mean_absolute_error: 1.5353 - val_loss: 10.8407 - val_mean_absolute_error: 2.2584
# Epoch 21/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.3066 - mean_absolute_error: 1.6446 - val_loss: 10.6207 - val_mean_absolute_error: 2.1502
# Epoch 22/100
# 57/57 [==============================] - 1s 12ms/step - loss: 4.7254 - mean_absolute_error: 1.5127 - val_loss: 12.7064 - val_mean_absolute_error: 2.5249
# Epoch 23/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.0443 - mean_absolute_error: 1.7981 - val_loss: 14.2712 - val_mean_absolute_error: 2.8117
# Epoch 24/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.6751 - mean_absolute_error: 1.9132 - val_loss: 10.6216 - val_mean_absolute_error: 2.2045
# Epoch 25/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.0631 - mean_absolute_error: 1.5873 - val_loss: 10.7921 - val_mean_absolute_error: 2.1560
# Epoch 26/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.7762 - mean_absolute_error: 1.7345 - val_loss: 10.6491 - val_mean_absolute_error: 2.1381
# Epoch 27/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.9389 - mean_absolute_error: 1.9435 - val_loss: 14.7185 - val_mean_absolute_error: 2.9712
# Epoch 28/100
# 57/57 [==============================] - 1s 12ms/step - loss: 9.5577 - mean_absolute_error: 2.3689 - val_loss: 14.7295 - val_mean_absolute_error: 3.0232
# Epoch 29/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.5495 - mean_absolute_error: 1.8576 - val_loss: 16.9676 - val_mean_absolute_error: 3.2041
# Epoch 30/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.2289 - mean_absolute_error: 1.8193 - val_loss: 11.2590 - val_mean_absolute_error: 2.2623
# Epoch 31/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.6237 - mean_absolute_error: 1.8821 - val_loss: 10.6905 - val_mean_absolute_error: 2.1307
# Epoch 32/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.6936 - mean_absolute_error: 1.7015 - val_loss: 11.7577 - val_mean_absolute_error: 2.3563
# Epoch 33/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.4991 - mean_absolute_error: 1.6922 - val_loss: 15.9250 - val_mean_absolute_error: 3.1764
# Epoch 34/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.4014 - mean_absolute_error: 1.8516 - val_loss: 10.8656 - val_mean_absolute_error: 2.2971
# Epoch 35/100
# 57/57 [==============================] - 1s 11ms/step - loss: 7.5522 - mean_absolute_error: 2.0731 - val_loss: 10.9607 - val_mean_absolute_error: 2.1856
# Epoch 36/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.3530 - mean_absolute_error: 1.6725 - val_loss: 11.0965 - val_mean_absolute_error: 2.2063
# Epoch 37/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.6767 - mean_absolute_error: 1.7304 - val_loss: 18.0764 - val_mean_absolute_error: 3.4669
# Epoch 38/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.2406 - mean_absolute_error: 1.8025 - val_loss: 15.1679 - val_mean_absolute_error: 2.9373
# Epoch 39/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.3675 - mean_absolute_error: 1.8649 - val_loss: 11.3669 - val_mean_absolute_error: 2.2990
# Epoch 40/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.9134 - mean_absolute_error: 1.7843 - val_loss: 10.7906 - val_mean_absolute_error: 2.1590
# Epoch 41/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.1828 - mean_absolute_error: 1.8041 - val_loss: 10.9020 - val_mean_absolute_error: 2.1874
# Epoch 42/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.5917 - mean_absolute_error: 1.8964 - val_loss: 27.9332 - val_mean_absolute_error: 4.5228
# Epoch 43/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.9278 - mean_absolute_error: 1.9468 - val_loss: 10.9695 - val_mean_absolute_error: 2.2034
# Epoch 44/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.9932 - mean_absolute_error: 1.8108 - val_loss: 18.0884 - val_mean_absolute_error: 3.3667
# Epoch 45/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.6613 - mean_absolute_error: 1.6965 - val_loss: 16.9780 - val_mean_absolute_error: 3.2072
# Epoch 46/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.3988 - mean_absolute_error: 1.6206 - val_loss: 10.6871 - val_mean_absolute_error: 2.1309
# Epoch 47/100
# 57/57 [==============================] - 1s 11ms/step - loss: 4.8878 - mean_absolute_error: 1.5163 - val_loss: 10.7045 - val_mean_absolute_error: 2.1579
# Epoch 48/100
# 57/57 [==============================] - 1s 12ms/step - loss: 9.4133 - mean_absolute_error: 2.3099 - val_loss: 11.3674 - val_mean_absolute_error: 2.2656
# Epoch 49/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.2246 - mean_absolute_error: 1.6438 - val_loss: 12.2931 - val_mean_absolute_error: 2.5420
# Epoch 50/100
# 57/57 [==============================] - 1s 16ms/step - loss: 5.1762 - mean_absolute_error: 1.6136 - val_loss: 11.5707 - val_mean_absolute_error: 2.3174
# Epoch 51/100
# 57/57 [==============================] - 1s 18ms/step - loss: 6.6498 - mean_absolute_error: 1.9354 - val_loss: 16.2969 - val_mean_absolute_error: 3.2061
# Epoch 52/100
# 57/57 [==============================] - 1s 18ms/step - loss: 7.9947 - mean_absolute_error: 2.1487 - val_loss: 14.8513 - val_mean_absolute_error: 2.9308
# Epoch 53/100
# 57/57 [==============================] - 1s 21ms/step - loss: 5.4385 - mean_absolute_error: 1.6601 - val_loss: 10.7273 - val_mean_absolute_error: 2.1754
# Epoch 54/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.1435 - mean_absolute_error: 1.7894 - val_loss: 21.4919 - val_mean_absolute_error: 3.8041
# Epoch 55/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.2984 - mean_absolute_error: 1.6399 - val_loss: 12.4319 - val_mean_absolute_error: 2.4915
# Epoch 56/100
# 57/57 [==============================] - 1s 13ms/step - loss: 5.8058 - mean_absolute_error: 1.7388 - val_loss: 11.8218 - val_mean_absolute_error: 2.3517
# Epoch 57/100
# 57/57 [==============================] - 1s 13ms/step - loss: 8.4696 - mean_absolute_error: 2.1292 - val_loss: 14.7668 - val_mean_absolute_error: 2.8676
# Epoch 58/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.4899 - mean_absolute_error: 1.7197 - val_loss: 10.8542 - val_mean_absolute_error: 2.2248
# Epoch 59/100
# 57/57 [==============================] - 1s 11ms/step - loss: 4.9832 - mean_absolute_error: 1.5791 - val_loss: 12.0902 - val_mean_absolute_error: 2.4562
# Epoch 60/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.1302 - mean_absolute_error: 1.8110 - val_loss: 10.9392 - val_mean_absolute_error: 2.2096
# Epoch 61/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.7173 - mean_absolute_error: 1.8592 - val_loss: 11.0378 - val_mean_absolute_error: 2.3122
# Epoch 62/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.2803 - mean_absolute_error: 1.8485 - val_loss: 12.9534 - val_mean_absolute_error: 2.5399
# Epoch 63/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.0076 - mean_absolute_error: 1.6114 - val_loss: 18.6325 - val_mean_absolute_error: 3.4371
# Epoch 64/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.8991 - mean_absolute_error: 1.7713 - val_loss: 11.8908 - val_mean_absolute_error: 2.4168
# Epoch 65/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.2678 - mean_absolute_error: 1.6342 - val_loss: 10.9017 - val_mean_absolute_error: 2.1875
# Epoch 66/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.2291 - mean_absolute_error: 1.8473 - val_loss: 11.6562 - val_mean_absolute_error: 2.4282
# Epoch 67/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.3381 - mean_absolute_error: 1.6528 - val_loss: 10.6622 - val_mean_absolute_error: 2.1813
# Epoch 68/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.3197 - mean_absolute_error: 1.7938 - val_loss: 24.4615 - val_mean_absolute_error: 4.1560
# Epoch 69/100
# 57/57 [==============================] - 1s 12ms/step - loss: 13.1508 - mean_absolute_error: 2.7203 - val_loss: 24.3610 - val_mean_absolute_error: 4.2423
# Epoch 70/100
# 57/57 [==============================] - 1s 12ms/step - loss: 7.8875 - mean_absolute_error: 2.0830 - val_loss: 18.3012 - val_mean_absolute_error: 3.4622
# Epoch 71/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.0579 - mean_absolute_error: 1.7778 - val_loss: 14.1418 - val_mean_absolute_error: 2.7825
# Epoch 72/100
# 57/57 [==============================] - 1s 13ms/step - loss: 7.2492 - mean_absolute_error: 1.9367 - val_loss: 11.7011 - val_mean_absolute_error: 2.3613
# Epoch 73/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.2206 - mean_absolute_error: 1.6294 - val_loss: 11.6676 - val_mean_absolute_error: 2.3728
# Epoch 74/100
# 57/57 [==============================] - 1s 13ms/step - loss: 7.4267 - mean_absolute_error: 2.0388 - val_loss: 19.7708 - val_mean_absolute_error: 3.6383
# Epoch 75/100
# 57/57 [==============================] - 1s 12ms/step - loss: 7.9253 - mean_absolute_error: 2.1055 - val_loss: 11.5427 - val_mean_absolute_error: 2.3718
# Epoch 76/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.5289 - mean_absolute_error: 1.8917 - val_loss: 12.1851 - val_mean_absolute_error: 2.4337
# Epoch 77/100
# 57/57 [==============================] - 1s 11ms/step - loss: 8.2184 - mean_absolute_error: 2.0876 - val_loss: 13.3176 - val_mean_absolute_error: 2.6457
# Epoch 78/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.1780 - mean_absolute_error: 1.8214 - val_loss: 11.3416 - val_mean_absolute_error: 2.2958
# Epoch 79/100
# 57/57 [==============================] - 1s 13ms/step - loss: 5.0012 - mean_absolute_error: 1.5766 - val_loss: 11.6833 - val_mean_absolute_error: 2.3385
# Epoch 80/100
# 57/57 [==============================] - 1s 11ms/step - loss: 4.9703 - mean_absolute_error: 1.5616 - val_loss: 11.6337 - val_mean_absolute_error: 2.3433
# Epoch 81/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.5879 - mean_absolute_error: 1.7085 - val_loss: 12.0482 - val_mean_absolute_error: 2.4469
# Epoch 82/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.7902 - mean_absolute_error: 1.7656 - val_loss: 10.8656 - val_mean_absolute_error: 2.1842
# Epoch 83/100
# 57/57 [==============================] - 1s 12ms/step - loss: 4.9267 - mean_absolute_error: 1.5583 - val_loss: 10.7336 - val_mean_absolute_error: 2.1489
# Epoch 84/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.7470 - mean_absolute_error: 1.6933 - val_loss: 14.0643 - val_mean_absolute_error: 2.8710
# Epoch 85/100
# 57/57 [==============================] - 1s 11ms/step - loss: 7.6599 - mean_absolute_error: 2.0134 - val_loss: 11.4498 - val_mean_absolute_error: 2.3163
# Epoch 86/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.2736 - mean_absolute_error: 1.6391 - val_loss: 11.7048 - val_mean_absolute_error: 2.3209
# Epoch 87/100
# 57/57 [==============================] - 1s 13ms/step - loss: 5.8412 - mean_absolute_error: 1.7661 - val_loss: 13.7977 - val_mean_absolute_error: 2.7135
# Epoch 88/100
# 57/57 [==============================] - 1s 12ms/step - loss: 5.6075 - mean_absolute_error: 1.7623 - val_loss: 10.7561 - val_mean_absolute_error: 2.1420
# Epoch 89/100
# 57/57 [==============================] - 1s 11ms/step - loss: 6.1195 - mean_absolute_error: 1.7968 - val_loss: 16.6352 - val_mean_absolute_error: 3.2668
# Epoch 90/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.4482 - mean_absolute_error: 1.8421 - val_loss: 12.8926 - val_mean_absolute_error: 2.6513
# Epoch 91/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.7392 - mean_absolute_error: 1.8911 - val_loss: 11.7575 - val_mean_absolute_error: 2.3554
# Epoch 92/100
# 57/57 [==============================] - 1s 11ms/step - loss: 7.2612 - mean_absolute_error: 2.0408 - val_loss: 19.6777 - val_mean_absolute_error: 3.5690
# Epoch 93/100
# 57/57 [==============================] - 1s 12ms/step - loss: 8.5979 - mean_absolute_error: 2.2266 - val_loss: 11.6865 - val_mean_absolute_error: 2.3292
# Epoch 94/100
# 57/57 [==============================] - 1s 12ms/step - loss: 8.6647 - mean_absolute_error: 2.2452 - val_loss: 15.7740 - val_mean_absolute_error: 3.1497
# Epoch 95/100
# 57/57 [==============================] - 1s 12ms/step - loss: 7.1819 - mean_absolute_error: 1.9540 - val_loss: 12.7822 - val_mean_absolute_error: 2.5510
# Epoch 96/100
# 57/57 [==============================] - 1s 11ms/step - loss: 5.5646 - mean_absolute_error: 1.7062 - val_loss: 11.4312 - val_mean_absolute_error: 2.3173
# Epoch 97/100
# 57/57 [==============================] - 1s 12ms/step - loss: 6.2362 - mean_absolute_error: 1.7871 - val_loss: 11.5020 - val_mean_absolute_error: 2.3371
# Epoch 98/100
# 57/57 [==============================] - 1s 12ms/step - loss: 9.0543 - mean_absolute_error: 2.2883 - val_loss: 10.8236 - val_mean_absolute_error: 2.1720
# Epoch 99/100
# 57/57 [==============================] - 1s 13ms/step - loss: 6.6538 - mean_absolute_error: 1.8750 - val_loss: 11.5863 - val_mean_absolute_error: 2.4056
# Epoch 100/100
# 57/57 [==============================] - 1s 13ms/step - loss: 5.5809 - mean_absolute_error: 1.6862 - val_loss: 12.1715 - val_mean_absolute_error: 2.4318

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               66560
#
#  dense (Dense)               (None, 64)                8256
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 91,521
# Trainable params: 91,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_predictions = model.predict(X_train).flatten()

plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])

# %%
results = model.evaluate(X_train, y_train)
# Out:
# 57/57 [==============================] - 0s 4ms/step - loss: 5.2399 - mean_absolute_error: 1.6634

# %%
val_predictions = model.predict(X_val).flatten()

plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.xticks(rotation = 45)
plt.legend(['Validation Predictions', 'Validation Observations'])

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.xticks(rotation = 45)
plt.legend(['Testing Predictions', 'Testing Observations'])

# %%
results = model.evaluate(X_test, y_test)
# Out:
# 8/8 [==============================] - 0s 4ms/step - loss: 8.3876 - mean_absolute_error: 2.3604

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions', 
            'Training Observations',
            'Validation Predictions', 
            'Validation Observations',
            'Testing Predictions', 
            'Testing Observations'])
